# %%
import numpy as np
import matplotlib.pyplot as plt

# A = np.array([[1, 2], [3, 4]])
# plt.imshow(A, cmap='gray')
# plt.show()

import pandas
from sklearn.datasets import make_blobs

data = make_blobs(n_samples=100, centers=6, n_features=2, random_state=42)
# plt.scatter(data[0][:, 0], data[0][:, 1], c=data[1])
# plt.show()

# %%
sum(data[0])
# Out:
# array([ -40.96047604,  -91.48421194, -426.56584378,  103.22503669])

# %%
data
# Out:
# (array([[ -8.25147066,   9.51397854],
#         [ -9.57530822,  10.85173112],
#         [ -2.97261532,   8.54855637],
#         [-10.96597948,   8.460372  ],
#         [ -8.73867639,   6.82004726],
#         [ -7.22234171,  -7.68238686],
#         [  5.00151486,   1.32804993],
#         [  4.1607046 ,   1.78751071],
#         [  4.6040528 ,   3.53781334],
#         [ -3.10983631,   8.72259238],
#         [ -3.6601912 ,   9.38998415],
#         [ -6.87451373,  -7.11469673],
#         [-10.43510383,   7.88334982],
#         [  4.52423055,   1.67206599],
#         [  5.45240466,   3.32940971],
#         [  2.5442418 ,   4.45843623],
#         [-10.03482507,  10.25459584],
#         [-10.65920261,   9.88066946],
#         [ -7.40938739,  -6.36684216],
#         [  3.88807475,   4.63528448],
#         [  2.98567636,   4.57423248],
#         [ -5.40173315,  -7.39837981],
#         [ -2.26723535,   7.10100588],
#         [ -7.69550494,   8.07545595],
#         [  1.04761856,   4.94853616],
#         [  3.18089581,   3.34076924],
#         [ -9.5301014 ,   8.25522675],
#         [  1.13278581,   3.34564127],
#         [ -9.41512919,   9.78351442],
#         [  4.98349713,   0.21012953],
#         [ -4.99344129,  -6.70553178],
#         [ -8.61086782,   8.63066567],
#         [  1.77691212,   3.40771539],
#         [-10.47216755,   9.55192215],
#         [  2.02013373,   2.79507219],
#         [  2.31537271,   3.44710014],
#         [ -2.97867201,   9.55684617],
#         [ -3.11090424,  10.86656431],
#         [ -3.05358035,   9.12520872],
#         [  3.96295684,   2.58484597],
#         [ -7.58168029,  -7.20777174],
#         [ -7.09929908,  -6.52299702],
#         [  4.97114227,   2.94871481],
#         [  3.53354386,   0.77696306],
#         [  2.28218303,   4.94327443],
#         [ -1.77073104,   9.18565441],
#         [  3.16135685,   1.25332548],
#         [ -8.87303953,   6.15484488],
#         [  2.27279309,   4.50789977],
#         [ -8.50525887,  10.4519991 ],
#         [ -9.8117729 ,  10.11219754],
#         [ -5.96422507,  -6.55135848],
#         [ -6.79258012,  -7.17911694],
#         [ -8.29499793,  -7.30075492],
#         [  4.56786871,   2.97670258],
#         [  1.34227551,   4.39370525],
#         [  2.29899103,   4.9886348 ],
#         [ -9.37421637,   8.15245826],
#         [ -3.4172217 ,   7.60198243],
#         [ -4.23411546,   8.4519986 ],
#         [ -7.68812079,  -7.38186664],
#         [ -3.52202874,   9.32853346],
#         [ -9.75775199,   8.87345732],
#         [ -7.27173534,  -8.34362454],
#         [-10.44581099,   7.50815677],
#         [ -8.77809755,   9.78676503],
#         [ -9.11507249,   9.32536813],
#         [ -9.23052275,   9.95898157],
#         [ -9.03068872,   7.62507026],
#         [ -9.85296695,  12.11836621],
#         [  0.78534952,   2.84099494],
#         [ -6.78254964,  -5.9114646 ],
#         [-10.75709897,   7.29700904],
#         [ -7.0409129 ,  -6.47605874],
#         [ -8.96264277,   8.54103949],
#         [  2.84436039,   6.05824454],
#         [  4.96396281,   1.5880874 ],
#         [-10.38899119,   7.39208589],
#         [  1.94519853,   4.50260353],
#         [ -7.43553345,   5.92167185],
#         [ -9.07327485,   9.91198299],
#         [ -6.6220768 ,  -6.95455551],
#         [ -9.90063147,   7.79711535],
#         [  5.00127444,   3.51120625],
#         [ -8.02481054,   6.0926586 ],
#         [ -2.30033403,   7.054616  ],
#         [  0.83099674,   4.81800516],
#         [ -1.68665271,   7.79344248],
#         [ -3.83738367,   9.21114736],
#         [ -2.44166942,   7.58953794],
#         [ -9.62158105,   7.0014614 ],
#         [  4.17924007,   3.03029191],
#         [ -6.58350691,  -6.61905432],
#         [ -6.78786641,  -8.86767851],
#         [ -8.04729581,   6.41413546],
#         [ -1.04354885,   8.78850983],
#         [ -9.82886408,   6.75722519],
#         [ -2.52269485,   7.9565752 ],
#         [  5.67087836,   2.9044498 ],
#         [  3.80066131,   1.66395731]]),
#  array([3, 5, 0, 5, 3, 2, 1, 1, 1, 0, 0, 2, 5, 1, 1, 4, 5, 5, 2, 4, 4, 2,
#         0, 3, 4, 4, 5, 4, 5, 1, 2, 3, 4, 5, 1, 4, 0, 0, 0, 1, 2, 2, 1, 1,
#         4, 0, 1, 3, 4, 5, 5, 2, 2, 2, 1, 4, 4, 5, 0, 0, 2, 0, 3, 2, 3, 3,
#         5, 5, 3, 5, 4, 2, 3, 2, 5, 4, 1, 3, 4, 3, 5, 2, 3, 1, 3, 0, 4, 0,
#         0, 0, 3, 1, 2, 2, 3, 0, 3, 0, 1, 1]))
